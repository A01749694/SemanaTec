# %% [markdown]
# # Ejemplo de un archivo de IPNB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("vgsales.csv")

# %%
df.head(10) #Primeras filas
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.tail(10) #Ultimas filas
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
numeric_columns = []
# for col in df.columns:
#     if df[col].dtype != "O":
#         numeric_columns.append(col)
numeric_columns = [col for col in df.columns if df[col].dtype != "O"] #Crear un arreglo con todos los elemento de la columna con list comprehension
object_columns = [col for col in df.columns if df[col].dtype == "O"]

# %%
df[numeric_columns].plot.box()
# Out:
# <Axes: >

# %%
for col in numeric_columns: 
    df[col].plot.box() #Plotea la gráfia de bigote con los datos de las columnas númericas
    plt.show()

# %%
for col in numeric_columns:
    df[col].plot.kde()
    plt.show() #Graficar la densidad de los datos

# %%
print("Medidas de tendencia central")
print(f"Suma : {df["Year"].sum()}")
print(f"Promedio : {df["Year"].mean()}")
print(f"Mediana : {df["Year"].median()}")
print(f"Moda : {df["Year"].mode()}") #No se acostumbra con datos númericos
print("Medidas de dispersión")
print(f"Desviación estándar : {df["Year"].std()}")
print(f"Varianza : {df["Year"].var()}")
print("Medidas de posición")
print(f"min: {df["Year"].min()}")
print(f"Q1: {df["Year"].quantile(0.25)}")
print(f"Q2: {df["Year"].quantile(0.5)}")
print(f"Q3: {df["Year"].quantile(0.75)}")
print(f"max: {df["Year"].max()}")
# Out:
# Medidas de tendencia central
# Suma : 32758598.0
# Promedio : 2006.4064433147546
# Mediana : 2007.0
# Moda : 0    2009.0
# Name: Year, dtype: float64
# Medidas de dispersión
# Desviación estándar : 5.828981114712805
# Varianza : 33.97702083567854
# Medidas de posición
# min: 1980.0
# Q1: 2003.0
# Q2: 2007.0
# Q3: 2010.0
# max: 2020.0

# %%
#df[máscara] para consultas
df[df["Year"] <= 1990][["Name", "Platform"]]
# Out:
#                                       Name Platform
# 1                        Super Mario Bros.      NES
# 5                                   Tetris       GB
# 9                                Duck Hunt      NES
# 18                       Super Mario World     SNES
# 21                        Super Mario Land       GB
# ...                                    ...      ...
# 11749                       Super Baseball     2600
# 12636                   Adventures of Lolo      NES
# 14335                            Alter Ego       PC
# 14507                              SimCity       PC
# 15867  Strongest Tokyo University Shogi DS       DS
#
# [221 rows x 2 columns]

# %%
#todos los juegos publicados por nintendo 
# / -> or
# & -> and
# ~ -> not
df[(df["Year"] > 2000) & (df["Publisher"] == "Nintendo")]["Name"]
# Out:
# 0                                               Wii Sports
# 2                                           Mario Kart Wii
# 3                                        Wii Sports Resort
# 6                                    New Super Mario Bros.
# 7                                                 Wii Play
#                                ...
# 16269                             Slide Adventure: Mag Kid
# 16357                 Mario vs. Donkey Kong: Tipping Stars
# 16456                             Art Academy: Home Studio
# 16473                                      Captain Rainbow
# 16542    Mario & Luigi: Paper Jam & Mario Kart 7 Double...
# Name: Name, Length: 502, dtype: object

# %%
#Mostrar todos los juegos del ps1/psx, saturn y n64
#df["Platform"].unique() #Muestra todos los valores de la columna sin repetición
# df[(df["Platform"] == "PS") | (df["Platform"] == "N64") | (df["Platform"] == "SAT")]["Name"]
df[df["Platform"].isin(["PS", "N64", "SAT"])]["Name"]
# Out:
# 46                      Super Mario 64
# 52                        Gran Turismo
# 63                       Mario Kart 64
# 66                   Final Fantasy VII
# 69                      Gran Turismo 2
#                      ...
# 16506    Samurai Shodown: Warrios Rage
# 16518                 Crossroad Crisis
# 16554                Psychic Detective
# 16579                PGA European Tour
# 16583                   Carmageddon 64
# Name: Name, Length: 1688, dtype: object

# %%
df["NA_Sales"].nlargest(3) # n datos más grandes
df["NA_Sales"].nsmallest(5) #n datos más pequeños
df.nsmallest(n=5, columns=["NA_Sales"])
# Out:
#      Rank                                               Name Platform    Year  \
# 214   215                           Monster Hunter Freedom 3      PSP  2010.0
# 338   339                                  Friend Collection       DS  2009.0
# 383   384                                   Monster Hunter 4      3DS  2013.0
# 402   403  English Training: Have Fun Improving Your Skills!       DS  2006.0
# 426   427               Dragon Quest VI: Maboroshi no Daichi     SNES  1995.0
#
#             Genre         Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 214  Role-Playing            Capcom       0.0      0.00      4.87
# 338          Misc          Nintendo       0.0      0.00      3.67
# 383  Role-Playing            Capcom       0.0      0.00      3.44
# 402          Misc          Nintendo       0.0      0.99      2.32
# 426  Role-Playing  Enix Corporation       0.0      0.00      3.19
#
#      Other_Sales  Global_Sales
# 214         0.00          4.87
# 338         0.00          3.67
# ...

# %%
#Tabla de frecuencia
# bins = rangos de datos 
df["Year"].value_counts(bins=10)
# Out:
# (2004.0, 2008.0]      4579
# (2008.0, 2012.0]      4486
# (2000.0, 2004.0]      2849
# (2012.0, 2016.0]      2086
# (1996.0, 2000.0]      1355
# (1992.0, 1996.0]       663
# (1979.959, 1984.0]     122
# (1988.0, 1992.0]       117
# (1984.0, 1988.0]        66
# (2016.0, 2020.0]         4
# Name: count, dtype: int64
